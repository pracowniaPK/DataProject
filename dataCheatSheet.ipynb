# %%
import math
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# # CheatSheet
#
#  - [pandas](#Pandas)
#  - [plotting](#Plotting)
#
# ## Pandas
# ### Creating

# %%
# list of dictionaries
sales = [{'account': 'Jones LLC', 'Jan': 150, 'Feb': 200, 'Mar': 140},
         {'account': 'Alpha Co',  'Jan': 200, 'Feb': 210, 'Mar': 215},
         {'account': 'Blue Inc',  'Jan': 50,  'Feb': 90,  'Mar': 95 }]
pd.DataFrame(sales)
# Out:
#    Feb  Jan  Mar    account
# 0  200  150  140  Jones LLC
# 1  210  200  215   Alpha Co
# 2   90   50   95   Blue Inc

# %%
# dictionary with lists
sales = {'account': ['Jones LLC', 'Alpha Co', 'Blue Inc'],
         'Jan': [150, 200, 50],
         'Feb': [200, 210, 90],
         'Mar': [140, 215, 95]}
pd.DataFrame(sales)
# Out:
#    Feb  Jan  Mar    account
# 0  200  150  140  Jones LLC
# 1  210  200  215   Alpha Co
# 2   90   50   95   Blue Inc

# %%
# listst of tuples
sales = [('Jones LLC', 150, 200, 50),
         ('Alpha Co', 200, 210, 90),
         ('Blue Inc', 140, 215, 95)]
labels = ['account', 'Jan', 'Feb', 'Mar']
pd.DataFrame(sales, columns=labels)
# Out:
#      account  Jan  Feb  Mar
# 0  Jones LLC  150  200   50
# 1   Alpha Co  200  210   90
# 2   Blue Inc  140  215   95

# %%
# list of %$@#!
sales = [('account', ['Jones LLC', 'Alpha Co', 'Blue Inc']),
         ('Jan', [150, 200, 50]),
         ('Feb', [200, 210, 90]),
         ('Mar', [140, 215, 95]),
         ]
df = pd.DataFrame.from_items(sales)
df
# Out:
#      account  Jan  Feb  Mar
# 0  Jones LLC  150  200  140
# 1   Alpha Co  200  210  215
# 2   Blue Inc   50   90   95

# %% [markdown]
# ### Zaznaczanie

# %%
df = df[['Jan', 'Feb', 'Mar', 'account']]
df
# Out:
#    Jan  Feb  Mar    account
# 0  150  200  140  Jones LLC
# 1  200  210  215   Alpha Co
# 2   50   90   95   Blue Inc

# %%
df.Jan
# Out:
# 0    150
# 1    200
# 2     50
# Name: Jan, dtype: int64

# %%
df.iloc[1,1:3]
# Out:
# Feb    210
# Mar    215
# Name: 1, dtype: object

# %%
df.loc[1,['Feb','Mar']]
# Out:
# Feb    210
# Mar    215
# Name: 1, dtype: object

# %%
df.Feb == 200
# Out:
# 0     True
# 1    False
# 2    False
# Name: Feb, dtype: bool

# %%
df[df.Feb == 200]
# Out:
#    Jan  Feb  Mar    account
# 0  150  200  140  Jones LLC

# %%
df[(df.Mar < 200) & (df.Feb >= 200)]
# Out:
#    Jan  Feb  Mar    account
# 0  150  200  140  Jones LLC

# %%
# Out:
# 0    150
# 1    200
# Name: Jan, dtype: int64

# %% [markdown]
# ## Plotting
# ### Pandas

# %%
df.plot.bar()

# %%
d_ = d.applymap(math.floor)
d_.iloc[:,2].value_counts().sort_index().plot.bar()

# %%
rs = np.random.RandomState(0)
n, p = 500, 4
d = pd.DataFrame(rs.normal(6, 2, (n, p)))
d = d.applymap(abs)
d[:5].plot.bar()

# %%
d.plot.hist(stacked=True)

# %%
d.plot.scatter(x=0, y=1)

# %%
d.plot.hexbin(x=0, y=1, gridsize=20)

# %% [markdown]
# ### Seaborn

# %%
sns.countplot(d_[0])

# %%
sns.distplot(d[0], bins=8, kde=False)
# Out:
# c:\users\pkacz\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6448: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.kdeplot(d[d[0] < 6][0])

# %%
sns.kdeplot(d[0],d[1])

# %%
sns.jointplot(data = d, x = 0, y = 1, kind='hex')
# Out:
# c:\users\pkacz\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6448: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
# sns.boxplot(data = d)
sns.violinplot(data = d)
